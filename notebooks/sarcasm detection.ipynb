# %%
import json
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, GlobalAveragePooling1D, Dense
import numpy as np

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 100

# %%
with open('data/sarcasm.json') as f:
    data = json.load(f)

# %%
sentences = []
labels = []
urls = []

for d in data:
    sentences.append(d['headline'])
    labels.append(d['is_sarcastic'])
    urls.append(d['article_link'])

# %%
train_size = int(len(sentences) * 0.8)

train_sentences = sentences[:train_size]
test_sentences = sentences[train_size:]
train_labels = labels[:train_size]
test_labels = labels[train_size:]

# convert labels to numpy arrays
train_labels = np.array(train_labels)
test_labels = np.array(test_labels)

# %%
tokenizer = Tokenizer(num_words=vocab_size, oov_token='<OOV>')
tokenizer.fit_on_texts(train_sentences)
word_index = tokenizer.word_index

# %%
word_index
# Out:
# {'<OOV>': 1,
#  'to': 2,
#  'of': 3,
#  'the': 4,
#  'in': 5,
#  'for': 6,
#  'a': 7,
#  'on': 8,
#  'and': 9,
#  'with': 10,
#  'is': 11,
#  'new': 12,
#  'trump': 13,
#  'man': 14,
#  'from': 15,
#  'at': 16,
#  'about': 17,
#  'you': 18,
#  'by': 19,
#  'this': 20,
#  'after': 21,
#  'up': 22,
#  'out': 23,
#  'be': 24,
#  'how': 25,
#  'that': 26,
#  'it': 27,
#  'as': 28,
#  'not': 29,
#  'are': 30,
#  'your': 31,
#  'what': 32,
#  'his': 33,
#  'all': 34,
#  'he': 35,
#  'who': 36,
#  'just': 37,
#  'has': 38,
#  'will': 39,
#  'more': 40,
#  'into': 41,
#  'one': 42,
#  'year': 43,
#  'report': 44,
#  'have': 45,
#  'over': 46,
#  'area': 47,
#  'why': 48,
#  'donald': 49,
#  'u': 50,
#  'day': 51,
#  'can': 52,
#  'says': 53,
#  's': 54,
#  'first': 55,
#  'woman': 56,
#  'time': 57,
#  'like': 58,
#  'get': 59,
#  'her': 60,
#  'old': 61,
#  "trump's": 62,
#  'no': 63,
#  'now': 64,
#  'off': 65,
#  'an': 66,
#  'life': 67,
#  'obama': 68,
#  'people': 69,
#  'than': 70,
#  'women': 71,
#  "'": 72,
#  'house': 73,
#  'back': 74,
#  'was': 75,
#  'still': 76,
#  'white': 77,
#  'make': 78,
#  'down': 79,
#  'clinton': 80,
#  'my': 81,
#  'when': 82,
#  '5': 83,
#  'if': 84,
#  'i': 85,
#  'americans': 86,
#  'world': 87,
#  'could': 88,
#  'we': 89,
#  'way': 90,
#  'do': 91,
#  'study': 92,
#  'before': 93,
#  'their': 94,
#  'most': 95,
#  'they': 96,
#  'family': 97,
#  'gop': 98,
#  "it's": 99,
#  'black': 100,
#  'best': 101,
#  'bill': 102,
#  'only': 103,
#  'should': 104,
#  'school': 105,
#  'him': 106,
#  'watch': 107,
#  'years': 108,
#  'would': 109,
#  '3': 110,
#  'but': 111,
#  'being': 112,
#  'really': 113,
#  'police': 114,
#  'so': 115,
#  'know': 116,
#  'video': 117,
#  'finds': 118,
#  'president': 119,
#  '10': 120,
#  "can't": 121,
#  'last': 122,
#  'going': 123,
#  'death': 124,
#  'american': 125,
#  'things': 126,
#  'show': 127,
#  'during': 128,
#  'against': 129,
#  'state': 130,
#  'hillary': 131,
#  'home': 132,
#  'good': 133,
#  'health': 134,
#  'she': 135,
#  'nation': 136,
#  'may': 137,
#  'or': 138,
#  'love': 139,
#  'need': 140,
#  'every': 141,
#  'say': 142,
#  '000': 143,
#  "'the": 144,
#  'gets': 145,
#  'work': 146,
#  'campaign': 147,
#  'right': 148,
#  'some': 149,
#  'take': 150,
#  '2': 151,
#  'big': 152,
#  'too': 153,
#  'our': 154,
#  'little': 155,
#  'mom': 156,
#  'getting': 157,
#  'party': 158,
#  'court': 159,
#  'parents': 160,
#  "here's": 161,
#  'john': 162,
#  'makes': 163,
#  'high': 164,
#  'news': 165,
#  'calls': 166,
#  'kids': 167,
#  'dead': 168,
#  '7': 169,
#  'where': 170,
#  'self': 171,
#  'child': 172,
#  'takes': 173,
#  'local': 174,
#  'other': 175,
#  'these': 176,
#  'election': 177,
#  'real': 178,
#  'while': 179,
#  'never': 180,
#  '4': 181,
#  'through': 182,
#  'own': 183,
#  "doesn't": 184,
#  'gay': 185,
#  'go': 186,
#  'see': 187,
#  "he's": 188,
#  'want': 189,
#  'america': 190,
#  'its': 191,
#  'college': 192,
#  "don't": 193,
#  'plan': 194,
#  'bush': 195,
#  'next': 196,
#  'stop': 197,
#  'even': 198,
#  'around': 199,
#  'change': 200,
#  'look': 201,
#  'war': 202,
#  'guy': 203,
#  'again': 204,
#  '6': 205,
#  '1': 206,
#  'sex': 207,
#  'another': 208,
#  'office': 209,
#  "nation's": 210,
#  'baby': 211,
#  'two': 212,
#  'made': 213,
#  'dog': 214,
#  'got': 215,
#  'million': 216,
#  'ever': 217,
#  'wants': 218,
#  'job': 219,
#  'thing': 220,
#  'dad': 221,
#  'them': 222,
#  'been': 223,
#  "man's": 224,
#  'week': 225,
#  'north': 226,
#  'care': 227,
#  'long': 228,
#  'congress': 229,
#  'gun': 230,
#  'much': 231,
#  'under': 232,
#  'actually': 233,
#  'debate': 234,
#  'help': 235,
#  'us': 236,
#  'national': 237,
#  'live': 238,
#  '9': 239,
#  'season': 240,
#  '20': 241,
#  'without': 242,
#  'ways': 243,
#  "won't": 244,
#  'shows': 245,
#  'students': 246,
#  'star': 247,
#  'finally': 248,
#  'anti': 249,
#  'give': 250,
#  'night': 251,
#  'had': 252,
#  'sexual': 253,
#  'making': 254,
#  'game': 255,
#  'there': 256,
#  'god': 257,
#  'couple': 258,
#  'senate': 259,
#  'shooting': 260,
#  'paul': 261,
#  'trying': 262,
#  'media': 263,
#  '8': 264,
#  'better': 265,
#  'entire': 266,
#  'climate': 267,
#  'free': 268,
#  'top': 269,
#  'money': 270,
#  'tell': 271,
#  'face': 272,
#  'everyone': 273,
#  'me': 274,
#  'city': 275,
#  'history': 276,
#  'away': 277,
#  'end': 278,
#  'tv': 279,
#  'law': 280,
#  'reveals': 281,
#  'supreme': 282,
#  'any': 283,
#  'part': 284,
#  'teen': 285,
#  'men': 286,
#  'children': 287,
#  'food': 288,
#  'attack': 289,
#  'story': 290,
#  'government': 291,
#  'business': 292,
#  'announces': 293,
#  'come': 294,
#  'movie': 295,
#  'bad': 296,
#  'film': 297,
#  'does': 298,
#  'son': 299,
#  'wedding': 300,
#  'single': 301,
#  'found': 302,
#  'fight': 303,
#  'deal': 304,
#  'introduces': 305,
#  'think': 306,
#  'body': 307,
#  'pope': 308,
#  'find': 309,
#  'york': 310,
#  'enough': 311,
#  'car': 312,
#  '11': 313,
#  'fire': 314,
#  'facebook': 315,
#  'girl': 316,
#  'james': 317,
#  'friends': 318,
#  'republican': 319,
#  'former': 320,
#  'looking': 321,
#  'thinks': 322,
#  'friend': 323,
#  'book': 324,
#  'morning': 325,
#  "didn't": 326,
#  'same': 327,
#  'already': 328,
#  'photos': 329,
#  'support': 330,
#  'must': 331,
#  'power': 332,
#  'public': 333,
#  'speech': 334,
#  'second': 335,
#  'call': 336,
#  'middle': 337,
#  'great': 338,
#  'tax': 339,
#  'used': 340,
#  'rights': 341,
#  'run': 342,
#  'keep': 343,
#  'asks': 344,
#  'behind': 345,
#  'line': 346,
#  'use': 347,
#  'future': 348,
#  'talk': 349,
#  'email': 350,
#  'christmas': 351,
#  'marriage': 352,
#  'security': 353,
#  'company': 354,
#  'room': 355,
#  'human': 356,
#  'republicans': 357,
#  'inside': 358,
#  'team': 359,
#  'claims': 360,
#  'coming': 361,
#  'sanders': 362,
#  'goes': 363,
#  'name': 364,
#  'because': 365,
#  'presidential': 366,
#  'violence': 367,
#  'open': 368,
#  'each': 369,
#  '2016': 370,
#  'democrats': 371,
#  'case': 372,
#  'voters': 373,
#  'control': 374,
#  'vote': 375,
#  'having': 376,
#  'might': 377,
#  'judge': 378,
#  'pretty': 379,
#  'ad': 380,
#  'secret': 381,
#  'wife': 382,
#  "world's": 383,
#  'once': 384,
#  '12': 385,
#  'department': 386,
#  'releases': 387,
#  'political': 388,
#  'ban': 389,
#  'win': 390,
#  'twitter': 391,
#  'student': 392,
#  'full': 393,
#  'perfect': 394,
#  'group': 395,
#  'between': 396,
#  'killed': 397,
#  'something': 398,
#  'doing': 399,
#  'sure': 400,
#  'texas': 401,
#  'very': 402,
#  'photo': 403,
#  'missing': 404,
#  'race': 405,
#  'poll': 406,
#  'fans': 407,
#  'teacher': 408,
#  'reports': 409,
#  'living': 410,
#  'kim': 411,
#  'female': 412,
#  'obamacare': 413,
#  'record': 414,
#  'person': 415,
#  'drug': 416,
#  'ryan': 417,
#  'comes': 418,
#  'boy': 419,
#  'always': 420,
#  'scientists': 421,
#  'three': 422,
#  'bernie': 423,
#  'until': 424,
#  '15': 425,
#  'art': 426,
#  'ready': 427,
#  'unveils': 428,
#  'super': 429,
#  'california': 430,
#  'shot': 431,
#  'meet': 432,
#  'days': 433,
#  'here': 434,
#  'put': 435,
#  'summer': 436,
#  'everything': 437,
#  'music': 438,
#  'were': 439,
#  'save': 440,
#  'lives': 441,
#  'post': 442,
#  'month': 443,
#  'gives': 444,
#  'candidate': 445,
#  'red': 446,
#  'looks': 447,
#  'minutes': 448,
#  'mother': 449,
#  'word': 450,
#  'country': 451,
#  'forced': 452,
#  'working': 453,
#  'korea': 454,
#  'water': 455,
#  'head': 456,
#  'fucking': 457,
#  'mike': 458,
#  'russia': 459,
#  'start': 460,
#  'thousands': 461,
#  'running': 462,
#  'wall': 463,
#  'many': 464,
#  'needs': 465,
#  'pay': 466,
#  'age': 467,
#  'social': 468,
#  'did': 469,
#  'eating': 470,
#  'leaves': 471,
#  'breaking': 472,
#  'list': 473,
#  'father': 474,
#  "you're": 475,
#  'class': 476,
#  'education': 477,
#  'admits': 478,
#  'employee': 479,
#  'probably': 480,
#  'town': 481,
#  'owner': 482,
#  'south': 483,
#  "'i": 484,
#  'dies': 485,
#  'tells': 486,
#  'cancer': 487,
#  "i'm": 488,
#  'past': 489,
#  'yet': 490,
#  'set': 491,
#  'left': 492,
#  'plans': 493,
#  'states': 494,
#  'taking': 495,
#  'talks': 496,
#  '30': 497,
#  'believe': 498,
#  'king': 499,
#  'let': 500,
#  'biden': 501,
#  'fbi': 502,
#  'street': 503,
#  'cruz': 504,
#  'lost': 505,
#  'wins': 506,
#  'dream': 507,
#  'military': 508,
#  'michael': 509,
#  'place': 510,
#  'justice': 511,
#  'letter': 512,
#  'isis': 513,
#  'hot': 514,
#  'director': 515,
#  'air': 516,
#  'secretary': 517,
#  'beautiful': 518,
#  'guide': 519,
#  'together': 520,
#  'chris': 521,
#  'heart': 522,
#  'times': 523,
#  'hard': 524,
#  'fan': 525,
#  'march': 526,
#  'lot': 527,
#  'internet': 528,
#  'excited': 529,
#  'service': 530,
#  'romney': 531,
#  'personal': 532,
#  'half': 533,
#  'nuclear': 534,
#  'congressman': 535,
#  'thought': 536,
#  'phone': 537,
#  'hollywood': 538,
#  '50': 539,
#  'wrong': 540,
#  'tips': 541,
#  'officials': 542,
#  'restaurant': 543,
#  'young': 544,
#  'warns': 545,
#  'rock': 546,
#  'questions': 547,
#  'those': 548,
#  'wearing': 549,
#  'crisis': 550,
#  'administration': 551,
#  'ice': 552,
#  'ex': 553,
#  'percent': 554,
#  'assault': 555,
#  'george': 556,
#  "what's": 557,
#  'buy': 558,
#  'small': 559,
#  "isn't": 560,
#  'tweets': 561,
#  'less': 562,
#  'nothing': 563,
#  'federal': 564,
#  'latest': 565,
#  'idea': 566,
#  'ceo': 567,
#  'muslim': 568,
#  'earth': 569,
#  't': 570,
#  'daughter': 571,
#  'problem': 572,
#  'move': 573,
#  'abortion': 574,
#  'shit': 575,
#  'message': 576,
#  'ask': 577,
#  'china': 578,
#  'knows': 579,
#  'iran': 580,
#  'girls': 581,
#  'sleep': 582,
#  'birthday': 583,
#  'holiday': 584,
#  'giving': 585,
#  'outside': 586,
#  'fox': 587,
#  "women's": 588,
#  'al': 589,
#  'celebrates': 590,
#  'kill': 591,
#  'florida': 592,
#  'washington': 593,
#  'few': 594,
#  'third': 595,
#  'birth': 596,
#  'someone': 597,
#  'online': 598,
#  'series': 599,
#  'ted': 600,
#  'told': 601,
#  'issues': 602,
#  'system': 603,
#  'cover': 604,
#  'response': 605,
#  'huffpost': 606,
#  'rise': 607,
#  'talking': 608,
#  'meeting': 609,
#  'majority': 610,
#  'feel': 611,
#  'chief': 612,
#  "america's": 613,
#  'following': 614,
#  'late': 615,
#  'special': 616,
#  'mark': 617,
#  "she's": 618,
#  'career': 619,
#  'moment': 620,
#  'trip': 621,
#  'rules': 622,
#  'read': 623,
#  'russian': 624,
#  'months': 625,
#  'cat': 626,
#  'stephen': 627,
#  'syrian': 628,
#  'bar': 629,
#  'box': 630,
#  'hour': 631,
#  'un': 632,
#  'hours': 633,
#  '2015': 634,
#  'fun': 635,
#  'community': 636,
#  'using': 637,
#  'travel': 638,
#  'thinking': 639,
#  'favorite': 640,
#  'billion': 641,
#  'today': 642,
#  'watching': 643,
#  'reason': 644,
#  'hair': 645,
#  'straight': 646,
#  'scott': 647,
#  'play': 648,
#  'victims': 649,
#  'prison': 650,
#  'fashion': 651,
#  'david': 652,
#  'democratic': 653,
#  'least': 654,
#  'union': 655,
#  'minute': 656,
#  'become': 657,
#  'kid': 658,
#  'adorable': 659,
#  'weekend': 660,
#  'break': 661,
#  'happy': 662,
#  'gift': 663,
#  'hope': 664,
#  'leave': 665,
#  'point': 666,
#  'taylor': 667,
#  'offers': 668,
#  'front': 669,
#  'anything': 670,
#  'since': 671,
#  'stars': 672,
#  'reasons': 673,
#  'visit': 674,
#  'bus': 675,
#  'kind': 676,
#  'global': 677,
#  'well': 678,
#  'date': 679,
#  'dating': 680,
#  'store': 681,
#  'k': 682,
#  'protest': 683,
#  'powerful': 684,
#  'lessons': 685,
#  'francis': 686,
#  'accused': 687,
#  'different': 688,
#  'crash': 689,
#  'c': 690,
#  'reality': 691,
#  'trailer': 692,
#  'senator': 693,
#  'order': 694,
#  'politics': 695,
#  'cop': 696,
#  'pence': 697,
#  'joe': 698,
#  'dinner': 699,
#  'millions': 700,
#  'syria': 701,
#  'worried': 702,
#  "obama's": 703,
#  'leader': 704,
#  'key': 705,
#  'far': 706,
#  'himself': 707,
#  'true': 708,
#  'conversation': 709,
#  'non': 710,
#  'spends': 711,
#  'learned': 712,
#  'called': 713,
#  'attacks': 714,
#  'j': 715,
#  'oil': 716,
#  'sports': 717,
#  'sick': 718,
#  '100': 719,
#  'surprise': 720,
#  'hands': 721,
#  'struggling': 722,
#  'discover': 723,
#  'names': 724,
#  'mass': 725,
#  'song': 726,
#  'lead': 727,
#  'opens': 728,
#  'feels': 729,
#  'hit': 730,
#  'policy': 731,
#  'schools': 732,
#  'immigration': 733,
#  'leaders': 734,
#  'stand': 735,
#  '2017': 736,
#  'apple': 737,
#  'adds': 738,
#  'cops': 739,
#  'd': 740,
#  'kills': 741,
#  'united': 742,
#  'hate': 743,
#  'brings': 744,
#  'low': 745,
#  'weird': 746,
#  'oscar': 747,
#  'tom': 748,
#  'kardashian': 749,
#  'return': 750,
#  'girlfriend': 751,
#  'relationship': 752,
#  'sign': 753,
#  'given': 754,
#  'returns': 755,
#  'reportedly': 756,
#  'huge': 757,
#  'vows': 758,
#  '40': 759,
#  'drunk': 760,
#  'workers': 761,
#  'breaks': 762,
#  "they're": 763,
#  'near': 764,
#  'bring': 765,
#  'anniversary': 766,
#  'test': 767,
#  'chinese': 768,
#  'turns': 769,
#  'steve': 770,
#  'waiting': 771,
#  'iowa': 772,
#  'signs': 773,
#  'general': 774,
#  'stage': 775,
#  'fighting': 776,
#  'host': 777,
#  'close': 778,
#  'magazine': 779,
#  'trans': 780,
#  'artist': 781,
#  'killing': 782,
#  'massive': 783,
#  'die': 784,
#  'major': 785,
#  'turn': 786,
#  'weight': 787,
#  'number': 788,
#  'rubio': 789,
#  'west': 790,
#  'spring': 791,
#  'nfl': 792,
#  'voice': 793,
#  'style': 794,
#  'whole': 795,
#  'possible': 796,
#  'five': 797,
#  'moving': 798,
#  'puts': 799,
#  'moms': 800,
#  'mind': 801,
#  'candidates': 802,
#  'prince': 803,
#  'chance': 804,
#  'early': 805,
#  'industry': 806,
#  'totally': 807,
#  'protesters': 808,
#  'suicide': 809,
#  'side': 810,
#  'program': 811,
#  'lose': 812,
#  'christian': 813,
#  '2014': 814,
#  'awards': 815,
#  'force': 816,
#  'members': 817,
#  'advice': 818,
#  'eat': 819,
#  'peace': 820,
#  'carolina': 821,
#  'transgender': 822,
#  'act': 823,
#  'door': 824,
#  'planned': 825,
#  'fall': 826,
#  'investigation': 827,
#  'oscars': 828,
#  'interview': 829,
#  'employees': 830,
#  'audience': 831,
#  'lgbt': 832,
#  'executive': 833,
#  'jr': 834,
#  'murder': 835,
#  'tour': 836,
#  'press': 837,
#  'official': 838,
#  'center': 839,
#  'decision': 840,
#  'hits': 841,
#  'abuse': 842,
#  'check': 843,
#  'asking': 844,
#  'longer': 845,
#  'responds': 846,
#  'driving': 847,
#  'push': 848,
#  'worst': 849,
#  'male': 850,
#  'road': 851,
#  'iraq': 852,
#  'google': 853,
#  'space': 854,
#  'loses': 855,
#  'easy': 856,
#  'important': 857,
#  'fails': 858,
#  'wait': 859,
#  'suspect': 860,
#  'seen': 861,
#  'jimmy': 862,
#  'keeps': 863,
#  'feeling': 864,
#  'fear': 865,
#  'almost': 866,
#  'light': 867,
#  'risk': 868,
#  'role': 869,
#  'michelle': 870,
#  'worth': 871,
#  'fuck': 872,
#  'leaving': 873,
#  'moore': 874,
#  'allegations': 875,
#  'final': 876,
#  'bowl': 877,
#  'dance': 878,
#  'halloween': 879,
#  'pro': 880,
#  'poor': 881,
#  '13': 882,
#  'completely': 883,
#  'hoping': 884,
#  'card': 885,
#  'picture': 886,
#  'playing': 887,
#  'sean': 888,
#  'pick': 889,
#  'try': 890,
#  'cut': 891,
#  'spot': 892,
#  'defense': 893,
#  'ben': 894,
#  'band': 895,
#  'pizza': 896,
#  'words': 897,
#  'amazon': 898,
#  'biggest': 899,
#  'coffee': 900,
#  'queer': 901,
#  'whether': 902,
#  'paris': 903,
#  'supporters': 904,
#  'science': 905,
#  'repeal': 906,
#  'begins': 907,
#  'across': 908,
#  'homeless': 909,
#  'planet': 910,
#  'hand': 911,
#  'harassment': 912,
#  'university': 913,
#  'governor': 914,
#  'success': 915,
#  'eyes': 916,
#  'voter': 917,
#  'doctor': 918,
#  'shares': 919,
#  'residents': 920,
#  'demands': 921,
#  'results': 922,
#  'hall': 923,
#  'starting': 924,
#  'urges': 925,
#  'williams': 926,
#  'green': 927,
#  'economy': 928,
#  'reminds': 929,
#  'which': 930,
#  'emotional': 931,
#  'ebola': 932,
#  'building': 933,
#  'celebrate': 934,
#  'documentary': 935,
#  'four': 936,
#  '17': 937,
#  'bathroom': 938,
#  'remember': 939,
#  "woman's": 940,
#  'chicago': 941,
#  'louis': 942,
#  'israel': 943,
#  "year's": 944,
#  'east': 945,
#  'cool': 946,
#  "there's": 947,
#  'mental': 948,
#  'leading': 949,
#  'action': 950,
#  "we're": 951,
#  'humans': 952,
#  'board': 953,
#  'harvey': 954,
#  'happens': 955,
#  'historical': 956,
#  'ferguson': 957,
#  'crowd': 958,
#  'suggests': 959,
#  'rally': 960,
#  'deep': 961,
#  "let's": 962,
#  'amazing': 963,
#  'chicken': 964,
#  'worse': 965,
#  'threat': 966,
#  'forward': 967,
#  'opening': 968,
#  'nearly': 969,
#  'mean': 970,
#  'nasa': 971,
#  'apologizes': 972,
#  'problems': 973,
#  'color': 974,
#  '18': 975,
#  'clearly': 976,
#  'arrested': 977,
#  'clean': 978,
#  "mother's": 979,
#  'scandal': 980,
#  'hurricane': 981,
#  'rest': 982,
#  'album': 983,
#  'deadly': 984,
#  'shop': 985,
#  'park': 986,
#  'uses': 987,
#  'teens': 988,
#  'reform': 989,
#  'holding': 990,
#  'coworker': 991,
#  'demand': 992,
#  'spend': 993,
#  'older': 994,
#  'reporter': 995,
#  'throws': 996,
#  'users': 997,
#  'hilarious': 998,
#  'pregnant': 999,
#  'hear': 1000,
#  ...}

# %%
train_sequences = tokenizer.texts_to_sequences(train_sentences)
train_padded = pad_sequences(train_sequences, maxlen=max_length, padding='post', truncating='post')

# %%
len(train_padded[0])
# Out:
# 100

# %%
test_sequences = tokenizer.texts_to_sequences(test_sentences)
test_padded = pad_sequences(test_sequences, maxlen=max_length, padding='post', truncating='post')

# %%
model = Sequential([
    Embedding(vocab_size, embedding_dim, input_length=max_length),
    GlobalAveragePooling1D(),
    Dense(24, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(train_padded, train_labels, epochs=30, validation_data=(test_padded, test_labels), verbose=2)
# Out:
# Epoch 1/30
# 668/668 - 2s - loss: 0.6742 - accuracy: 0.5715 - val_loss: 0.6124 - val_accuracy: 0.7741
# Epoch 2/30
# 668/668 - 1s - loss: 0.4528 - accuracy: 0.8221 - val_loss: 0.3866 - val_accuracy: 0.8383
# Epoch 3/30
# 668/668 - 1s - loss: 0.3178 - accuracy: 0.8714 - val_loss: 0.3585 - val_accuracy: 0.8416
# Epoch 4/30
# 668/668 - 2s - loss: 0.2665 - accuracy: 0.8953 - val_loss: 0.3424 - val_accuracy: 0.8553
# Epoch 5/30
# 668/668 - 2s - loss: 0.2308 - accuracy: 0.9100 - val_loss: 0.3433 - val_accuracy: 0.8516
# Epoch 6/30
# 668/668 - 2s - loss: 0.2033 - accuracy: 0.9223 - val_loss: 0.3499 - val_accuracy: 0.8525
# Epoch 7/30
# 668/668 - 2s - loss: 0.1814 - accuracy: 0.9325 - val_loss: 0.3608 - val_accuracy: 0.8525
# Epoch 8/30
# 668/668 - 3s - loss: 0.1623 - accuracy: 0.9390 - val_loss: 0.3758 - val_accuracy: 0.8501
# Epoch 9/30
# 668/668 - 2s - loss: 0.1474 - accuracy: 0.9466 - val_loss: 0.3932 - val_accuracy: 0.8517
# Epoch 10/30
# 668/668 - 1s - loss: 0.1348 - accuracy: 0.9504 - val_loss: 0.4132 - val_accuracy: 0.8456
# Epoch 11/30
# 668/668 - 1s - loss: 0.1234 - accuracy: 0.9569 - val_loss: 0.4331 - val_accuracy: 0.8454
# Epoch 12/30
# 668/668 - 2s - loss: 0.1122 - accuracy: 0.9614 - val_loss: 0.4572 - val_accuracy: 0.8450
# Epoch 13/30
# 668/668 - 2s - loss: 0.1037 - accuracy: 0.9656 - val_loss: 0.4792 - val_accuracy: 0.8405
# Epoch 14/30
# 668/668 - 1s - loss: 0.0966 - accuracy: 0.9671 - val_loss: 0.5057 - val_accuracy: 0.8383
# Epoch 15/30
# 668/668 - 1s - loss: 0.0893 - accuracy: 0.9706 - val_loss: 0.5346 - val_accuracy: 0.8334
# Epoch 16/30
# 668/668 - 2s - loss: 0.0833 - accuracy: 0.9725 - val_loss: 0.5579 - val_accuracy: 0.8345
# Epoch 17/30
# 668/668 - 1s - loss: 0.0763 - accuracy: 0.9751 - val_loss: 0.5978 - val_accuracy: 0.8334
# Epoch 18/30
# 668/668 - 1s - loss: 0.0697 - accuracy: 0.9775 - val_loss: 0.6175 - val_accuracy: 0.8334
# Epoch 19/30
# 668/668 - 1s - loss: 0.0661 - accuracy: 0.9787 - val_loss: 0.6471 - val_accuracy: 0.8321
# Epoch 20/30
# 668/668 - 1s - loss: 0.0606 - accuracy: 0.9816 - val_loss: 0.6782 - val_accuracy: 0.8287
# Epoch 21/30
# 668/668 - 1s - loss: 0.0560 - accuracy: 0.9828 - val_loss: 0.7115 - val_accuracy: 0.8276
# Epoch 22/30
# 668/668 - 1s - loss: 0.0542 - accuracy: 0.9831 - val_loss: 0.7431 - val_accuracy: 0.8250
# Epoch 23/30
# 668/668 - 2s - loss: 0.0484 - accuracy: 0.9866 - val_loss: 0.7871 - val_accuracy: 0.8250
# Epoch 24/30
# 668/668 - 1s - loss: 0.0460 - accuracy: 0.9861 - val_loss: 0.8132 - val_accuracy: 0.8231
# Epoch 25/30
# 668/668 - 1s - loss: 0.0418 - accuracy: 0.9880 - val_loss: 0.8453 - val_accuracy: 0.8227
# Epoch 26/30
# 668/668 - 1s - loss: 0.0398 - accuracy: 0.9886 - val_loss: 0.8727 - val_accuracy: 0.8154
# Epoch 27/30
# 668/668 - 2s - loss: 0.0388 - accuracy: 0.9877 - val_loss: 0.9377 - val_accuracy: 0.8186
# Epoch 28/30
# 668/668 - 1s - loss: 0.0364 - accuracy: 0.9895 - val_loss: 0.9392 - val_accuracy: 0.8121
# Epoch 29/30
# 668/668 - 1s - loss: 0.0333 - accuracy: 0.9908 - val_loss: 1.0234 - val_accuracy: 0.8130
# Epoch 30/30
# 668/668 - 1s - loss: 0.0289 - accuracy: 0.9923 - val_loss: 1.0088 - val_accuracy: 0.8111

# %%
sentence = [
    'granny starting to fear spiders in the garden might be real',
    'the weather today is bright and sunny'
]

sequences = tokenizer.texts_to_sequences(sentence)
padded = pad_sequences(sequences, maxlen=max_length, padding='post', truncating='post')

# %%
model.predict(padded)
# Out:
# array([[9.8498428e-01],
#        [2.3248792e-04]], dtype=float32)
